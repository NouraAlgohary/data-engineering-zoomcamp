# %%
import time
import pandas as pd
from sqlalchemy import create_engine

# %%
yellow_taxi_data = pd.read_parquet('yellow_tripdata_2021-01.parquet')

# %%
yellow_taxi_data.to_csv('yellow_tripdata_2021-01.csv', index=False)

# %%
yellow_taxi_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3         11.80                   2.5          NaN
# 1                    0.3          4.30                   0.0          NaN
# 2                    0.3         51.95                   0.0          NaN
# 3                    0.3         36.35                   0.0          NaN
# 4                    0.3         24.36                   2.5          NaN

# %%
yellow_taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1369769 entries, 0 to 1369768
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1369769 non-null  int64
#  1   tpep_pickup_datetime   1369769 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  1369769 non-null  datetime64[us]
#  3   passenger_count        1271417 non-null  float64
#  4   trip_distance          1369769 non-null  float64
#  5   RatecodeID             1271417 non-null  float64
#  6   store_and_fwd_flag     1271417 non-null  object
#  7   PULocationID           1369769 non-null  int64
#  8   DOLocationID           1369769 non-null  int64
#  9   payment_type           1369769 non-null  int64
#  10  fare_amount            1369769 non-null  float64
#  11  extra                  1369769 non-null  float64
#  12  mta_tax                1369769 non-null  float64
#  13  tip_amount             1369769 non-null  float64
#  14  tolls_amount           1369769 non-null  float64
#  15  improvement_surcharge  1369769 non-null  float64
#  16  total_amount           1369769 non-null  float64
#  17  congestion_surcharge   1271417 non-null  float64
#  18  airport_fee            5 non-null        float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# memory usage: 198.6+ MB

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

engine.connect()

# %%
pd.io.sql.get_schema(yellow_taxi_data, name="yellow_taxi_data")
# Out:
# 'CREATE TABLE "yellow_taxi_data" (\n"VendorID" INTEGER,\n  "tpep_pickup_datetime" TIMESTAMP,\n  "tpep_dropoff_datetime" TIMESTAMP,\n  "passenger_count" REAL,\n  "trip_distance" REAL,\n  "RatecodeID" REAL,\n  "store_and_fwd_flag" TEXT,\n  "PULocationID" INTEGER,\n  "DOLocationID" INTEGER,\n  "payment_type" INTEGER,\n  "fare_amount" REAL,\n  "extra" REAL,\n  "mta_tax" REAL,\n  "tip_amount" REAL,\n  "tolls_amount" REAL,\n  "improvement_surcharge" REAL,\n  "total_amount" REAL,\n  "congestion_surcharge" REAL,\n  "airport_fee" REAL\n)'

# %%
df_structure = yellow_taxi_data.head(0)

df_structure
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
df_structure.to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
i = 0
chunk_size = 10000

while i < len(yellow_taxi_data):
    t_start = time.time()

    yellow_taxi_data[i:i + chunk_size].to_sql(
        name="yellow_taxi_data", 
        con=engine, 
        if_exists="append"
    )

    i += chunk_size
    t_end = time.time()

    print('Inserted another chunk... took %.3f second(s)' % (t_end - t_start))

print("Insertion is compelete")
# Out:
# Inserted another chunk... took 0.636 second(s)
# Inserted another chunk... took 0.491 second(s)
# Inserted another chunk... took 0.496 second(s)
# Inserted another chunk... took 0.569 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.525 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.483 second(s)
# Inserted another chunk... took 0.626 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.526 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.562 second(s)
# Inserted another chunk... took 0.475 second(s)
# Inserted another chunk... took 0.487 second(s)
# Inserted another chunk... took 0.525 second(s)
# Inserted another chunk... took 0.490 second(s)
# Inserted another chunk... took 0.486 second(s)
# Inserted another chunk... took 0.568 second(s)
# Inserted another chunk... took 0.483 second(s)
# Inserted another chunk... took 0.525 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.495 second(s)
# Inserted another chunk... took 0.615 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.528 second(s)
# Inserted another chunk... took 0.487 second(s)
# Inserted another chunk... took 0.534 second(s)
# Inserted another chunk... took 0.569 second(s)
# Inserted another chunk... took 0.483 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.530 second(s)
# Inserted another chunk... took 0.478 second(s)
# Inserted another chunk... took 0.576 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.494 second(s)
# Inserted another chunk... took 0.550 second(s)
# Inserted another chunk... took 0.485 second(s)
# Inserted another chunk... took 0.503 second(s)
# Inserted another chunk... took 0.503 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.537 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.571 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.528 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.483 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.563 second(s)
# Inserted another chunk... took 0.529 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.485 second(s)
# Inserted another chunk... took 0.621 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.474 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.613 second(s)
# Inserted another chunk... took 0.477 second(s)
# Inserted another chunk... took 0.474 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.527 second(s)
# Inserted another chunk... took 0.564 second(s)
# Inserted another chunk... took 0.472 second(s)
# Inserted another chunk... took 0.475 second(s)
# Inserted another chunk... took 0.484 second(s)
# Inserted another chunk... took 0.524 second(s)
# Inserted another chunk... took 0.483 second(s)
# Inserted another chunk... took 0.571 second(s)
# Inserted another chunk... took 0.470 second(s)
# Inserted another chunk... took 0.508 second(s)
# Inserted another chunk... took 0.489 second(s)
# Inserted another chunk... took 0.528 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.561 second(s)
# Inserted another chunk... took 0.475 second(s)
# Inserted another chunk... took 0.474 second(s)
# Inserted another chunk... took 0.535 second(s)
# Inserted another chunk... took 0.475 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.565 second(s)
# Inserted another chunk... took 0.474 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.527 second(s)
# Inserted another chunk... took 0.477 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.576 second(s)
# Inserted another chunk... took 0.536 second(s)
# Inserted another chunk... took 0.475 second(s)
# Inserted another chunk... took 0.485 second(s)
# Inserted another chunk... took 0.486 second(s)
# Inserted another chunk... took 0.486 second(s)
# Inserted another chunk... took 0.568 second(s)
# Inserted another chunk... took 0.530 second(s)
# Inserted another chunk... took 0.477 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.477 second(s)
# Inserted another chunk... took 0.492 second(s)
# Inserted another chunk... took 0.620 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.481 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.489 second(s)
# Inserted another chunk... took 0.606 second(s)
# Inserted another chunk... took 0.476 second(s)
# Inserted another chunk... took 0.487 second(s)
# Inserted another chunk... took 0.480 second(s)
# Inserted another chunk... took 0.496 second(s)
# Inserted another chunk... took 0.545 second(s)
# Inserted another chunk... took 0.540 second(s)
# Inserted another chunk... took 0.482 second(s)
# Inserted another chunk... took 0.489 second(s)
# Inserted another chunk... took 0.478 second(s)
# Inserted another chunk... took 0.479 second(s)
# Inserted another chunk... took 0.504 second(s)
# Inserted another chunk... took 0.543 second(s)
# Inserted another chunk... took 0.456 second(s)
# Inserted another chunk... took 0.449 second(s)
# Inserted another chunk... took 0.445 second(s)
# Inserted another chunk... took 0.502 second(s)
# Inserted another chunk... took 0.447 second(s)
# Inserted another chunk... took 0.537 second(s)
# Inserted another chunk... took 0.433 second(s)
# Inserted another chunk... took 0.434 second(s)
